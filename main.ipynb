# %%
from src.embedding import huggingface_embeddings
from src.vectorstore import load_vectorstore
from src.prompt import medical_information_prompt
from src.ollama_chain import create_rag_chain

# %%
embeddings = huggingface_embeddings()
# Out:
# [INFO] HuggingFace Embedding model Initializing...
#
# [INFO] Using device: cpu
# [INFO] Model loaded successfully on CPU
# ==================================================

# %%
vectorstore = load_vectorstore(
    embeddings=embeddings,
    vectorstore_path="faiss_index"

)
# Out:
# [INFO] Vector dimension: 384
# [INFO] Total Vectors in the store: <182191>
# ==================================================
#
# ✅✅ Successfully LOADED Vectorstore.

# %%
prompt = medical_information_prompt()

# %%
chain = create_rag_chain(vectorstore=vectorstore, prompt=prompt)
# Out:
# 🚀 Initializing RAG chain...
# ✅✅ RAG chain created successfully!
# ============================================================

# %%
query = "What are the common symptoms of diabetes?"

# %%
response = chain.invoke({
    "input": query
})
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(response["answer"])
# Out:
# **Causes:** Diabetes is primarily caused by insulin resistance (Type 2) or autoimmune destruction of insulin-producing cells (Type 1). Risk factors include obesity, family history, and physical inactivity. 📋 This requires professional medical diagnosis.
#
# **Symptoms:**
# • Increased thirst and urination
# • Unexplained weight loss
# • Excessive hunger and fatigue
#
# **Treatment Options:** Management focuses on blood sugar control through lifestyle changes like diet and exercise, oral medications, or insulin therapy, depending on the type and severity.
#
# **Medicines:**
# • Metformin
# • Insulin
# • Sulfonylureas
#
# **Prevention:**
# • Maintain a healthy weight
# • Engage in regular physical activity
# • Eat a balanced, low-sugar diet
#
# 💊 Consult doctor before starting any medication.
